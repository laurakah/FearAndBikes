# %%
import pandas as pd
import numpy as np
import re

# %%
df = pd.read_csv("../data_raw/global_terrorism.csv")

# %%
pd.set_option("display.max_columns", 500)
pd.options.display.max_rows = 100
df
# Out:
#      Unnamed: 0       eventid  iyear  imonth  iday approxdate  extended  \
# 0         77361  200501020019   2005       1     2        NaN         0
# 1         77694  200503190010   2005       3    19        NaN         0
# 2         77709  200503200012   2005       3    20        NaN         0
# 3         77746  200503260006   2005       3    26        NaN         0
# 4         77757  200503280004   2005       3    28        NaN         0
# ..          ...           ...    ...     ...   ...        ...       ...
# 852      181128  201712070017   2017      12     7        NaN         0
# 853      181488  201712230009   2017      12    23        NaN         0
# 854      181535  201712250021   2017      12    25        NaN         0
# 855      181556  201712260017   2017      12    26        NaN         0
# 856      181664  201712300022   2017      12    30        NaN         0
#
#     resolution  country     country_txt  region      region_txt  \
# ...

# %%
lst = df.columns

# %%
list(lst)
# Out:
# ['Unnamed: 0',
#  'eventid',
#  'iyear',
#  'imonth',
#  'iday',
#  'approxdate',
#  'extended',
#  'resolution',
#  'country',
#  'country_txt',
#  'region',
#  'region_txt',
#  'provstate',
#  'city',
#  'latitude',
#  'longitude',
#  'specificity',
#  'vicinity',
#  'location',
#  'summary',
#  'crit1',
#  'crit2',
#  'crit3',
#  'doubtterr',
#  'alternative',
#  'alternative_txt',
#  'multiple',
#  'success',
#  'suicide',
#  'attacktype1',
#  'attacktype1_txt',
#  'attacktype2',
#  'attacktype2_txt',
#  'attacktype3',
#  'attacktype3_txt',
#  'targtype1',
#  'targtype1_txt',
#  'targsubtype1',
#  'targsubtype1_txt',
#  'corp1',
#  'target1',
#  'natlty1',
#  'natlty1_txt',
#  'targtype2',
#  'targtype2_txt',
#  'targsubtype2',
#  'targsubtype2_txt',
#  'corp2',
#  'target2',
#  'natlty2',
#  'natlty2_txt',
#  'targtype3',
#  'targtype3_txt',
#  'targsubtype3',
#  'targsubtype3_txt',
#  'corp3',
#  'target3',
#  'natlty3',
#  'natlty3_txt',
#  'gname',
#  'gsubname',
# ...

# %%
columns_name = [ 
'eventid',
'iyear',
'imonth',
'iday',
'approxdate',
'country_txt',
'provstate',
'city',
'location',
'summary',
'multiple',
'success',
'suicide',
'attacktype1_txt',
'targtype1_txt',
'targsubtype1_txt',
'gname',
'individual',
'nperps',
'nkill',
'nwound',
'propvalue',
'weaptype1_txt']

# %%
columns_name
# Out:
# ['eventid',
#  'iyear',
#  'imonth',
#  'iday',
#  'approxdate',
#  'country_txt',
#  'provstate',
#  'city',
#  'location',
#  'summary',
#  'multiple',
#  'success',
#  'suicide',
#  'attacktype1_txt',
#  'targtype1_txt',
#  'targsubtype1_txt',
#  'gname',
#  'individual',
#  'nperps',
#  'nkill',
#  'nwound',
#  'propvalue',
#  'weaptype1_txt']

# %%
df = df[columns_name]

# %%
df.dtypes
# Out:
# eventid               int64
# iyear                 int64
# imonth                int64
# iday                  int64
# approxdate           object
# country_txt          object
# provstate            object
# city                 object
# location             object
# summary              object
# multiple            float64
# success               int64
# suicide               int64
# attacktype1_txt      object
# targtype1_txt        object
# targsubtype1_txt     object
# gname                object
# individual            int64
# nperps              float64
# nkill               float64
# nwound              float64
# propvalue           float64
# weaptype1_txt        object
# dtype: object

# %%
df["nkill"].value_counts()
# Out:
# 0.0     825
# 1.0      23
# 2.0       2
# 11.0      1
# 23.0      1
# 6.0       1
# 14.0      1
# 7.0       1
# 27.0      1
# 8.0       1
# Name: nkill, dtype: int64

# %%
col_to_np_nan_to_int64= ['nperps']

# %%
for col in col_to_np_nan_to_int64:
    df[col] =df[col].replace(-99, np.nan)
    df[col] =df[col].astype(pd.Int64Dtype())
# Out:
# /Users/nadavsmith/miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /Users/nadavsmith/miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %% [markdown]
# ## no real values in the propvalue col >  going to drop it.

# %%
df['propvalue'].value_counts()
# Out:
# -99.0    291
#  0.0       1
# Name: propvalue, dtype: int64

# %%
col_to_int = ['nkill', 'nwound']

# %%
for col in col_to_int:
    df[col] = df[col].astype(pd.Int64Dtype())
# Out:
# /Users/nadavsmith/miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
col_to_bol = ['multiple', 'individual', 'success', 'suicide']

# %%
df['suicide'].value_counts()
# Out:
# 0    850
# 1      7
# Name: suicide, dtype: int64

# %%
for col in col_to_bol:
    df[col] = df[col].astype("bool")
# Out:
# /Users/nadavsmith/miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df.dtypes
# Out:
# eventid               int64
# iyear                 int64
# imonth                int64
# iday                  int64
# approxdate           object
# country_txt          object
# provstate            object
# city                 object
# location             object
# summary              object
# multiple               bool
# success                bool
# suicide                bool
# attacktype1_txt      object
# targtype1_txt        object
# targsubtype1_txt     object
# gname                object
# individual             bool
# nperps                Int64
# nkill                 Int64
# nwound                Int64
# propvalue           float64
# weaptype1_txt        object
# dtype: object

# %%
df['nperps'].isnull().sum()
# Out:
# 714

# %%
df["nperps"].value_counts()
# Out:
# 1      70
# 2      38
# 3      24
# 4       6
# 5       2
# 6       1
# 15      1
# 700     1
# Name: nperps, dtype: int64

# %%
df["nperps"].isnull().sum()
# Out:
# 714

# %%
test = df['nperps'].replace(-99, np.nan)

# %%
test.astype(pd.Int64Dtype())
# Out:
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
#       ...
# 852    NaN
# 853    NaN
# 854      1
# 855    NaN
# 856    NaN
# Name: nperps, Length: 857, dtype: Int64

# %%
test.isnull().sum()
# Out:
# 714

# %%
df.head()
# Out:
#         eventid  iyear  imonth  iday approxdate     country_txt  \
# 0  200501020019   2005       1     2        NaN  United Kingdom
# 1  200503190010   2005       3    19        NaN  United Kingdom
# 2  200503200012   2005       3    20        NaN  United Kingdom
# 3  200503260006   2005       3    26        NaN  United Kingdom
# 4  200503280004   2005       3    28        NaN  United Kingdom
#
#           provstate         city  \
# 0  Northern Ireland       Kilrea
# 1  Northern Ireland      Belfast
# 2  Northern Ireland      Belfast
# 3  Northern Ireland       Antrim
# 4  Northern Ireland  Newtownards
#
#                                             location  \
# 0                              Derry City (District)
# 1  Antrim (County). The north section of the city...
# 2  Antrim (County). Gunnell Hill in the Whitewell...
# 3                                      County Antrim
# 4  The incident occurred at the Ards Shopping Cen...
#
# ...

# %%
df["iday"] = df["iday"].replace(0, 19)
# Out:
# /Users/nadavsmith/miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df[df["iday"] == 0]
# Out:
# Empty DataFrame
# Columns: [eventid, iyear, imonth, iday, approxdate, country_txt, provstate, city, location, summary, multiple, success, suicide, attacktype1_txt, targtype1_txt, targsubtype1_txt, gname, individual, nperps, nkill, nwound, propvalue, weaptype1_txt]
# Index: []

# %%
date = pd.DataFrame({'year' : list(df['iyear']),
                       'month' : list(df['imonth']),
                       'day' : list(df['iday'])})

# %%
date_col = pd.to_datetime(date)

# %%
date_col.rename("Date", inplace = True)
# Out:
# 0     2005-01-02
# 1     2005-03-19
# 2     2005-03-20
# 3     2005-03-26
# 4     2005-03-28
#          ...
# 852   2017-12-07
# 853   2017-12-23
# 854   2017-12-25
# 855   2017-12-26
# 856   2017-12-30
# Name: Date, Length: 857, dtype: datetime64[ns]

# %%
df = pd.merge(df, date_col, left_index=True, right_index = True)

# %%
df.drop(["iyear", "imonth", "iday", "approxdate", "country_txt", "propval"], axis = 1, inplace = True )

# %%
df.head()
# Out:
#         eventid         provstate         city  \
# 0  200501020019  Northern Ireland       Kilrea
# 1  200503190010  Northern Ireland      Belfast
# 2  200503200012  Northern Ireland      Belfast
# 3  200503260006  Northern Ireland       Antrim
# 4  200503280004  Northern Ireland  Newtownards
#
#                                             location  \
# 0                              Derry City (District)
# 1  Antrim (County). The north section of the city...
# 2  Antrim (County). Gunnell Hill in the Whitewell...
# 3                                      County Antrim
# 4  The incident occurred at the Ards Shopping Cen...
#
#                                              summary  multiple  success  \
# 0  01/02/2005: A pipe bomb was placed outside the...     False    False
# 1  03/19/2005: A petrol bomb was thrown at the ho...     False     True
# 2  03/20/2005: A petrol bomb was thrown into a ho...     False     True
# ...
