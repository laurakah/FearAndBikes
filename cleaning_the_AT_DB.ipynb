# %%
import pandas as pd
import numpy as np
import re

# %%
df = pd.read_excel("UK_TA_05_19.xlsx")

# %%
pd.set_option("display.max_columns", 500)
pd.options.display.max_rows = 100
df
# Out:
#           eventid  iyear  imonth  iday approxdate  extended  resolution  \
# 0    200501020019   2005       1     2        NaN         0         NaN
# 1    200503190010   2005       3    19        NaN         0         NaN
# 2    200503200012   2005       3    20        NaN         0         NaN
# 3    200503260006   2005       3    26        NaN         0         NaN
# 4    200503280004   2005       3    28        NaN         0         NaN
# ..            ...    ...     ...   ...        ...       ...         ...
# 953  201812200027   2018      12    20        NaN         0         NaN
# 954  201812230034   2018      12    23        NaN         0         NaN
# 955  201812270022   2018      12    27        NaN         0         NaN
# 956  201812310012   2018      12    31        NaN         0         NaN
# 957  201812310034   2018      12    31        NaN         0         NaN
#
#      country     country_txt  region      region_txt         provstate  \
# ...

# %%
lst = df.columns

# %%
list(lst)
# Out:
# ['eventid',
#  'iyear',
#  'imonth',
#  'iday',
#  'approxdate',
#  'extended',
#  'resolution',
#  'country',
#  'country_txt',
#  'region',
#  'region_txt',
#  'provstate',
#  'city',
#  'latitude',
#  'longitude',
#  'specificity',
#  'vicinity',
#  'location',
#  'summary',
#  'crit1',
#  'crit2',
#  'crit3',
#  'doubtterr',
#  'alternative',
#  'alternative_txt',
#  'multiple',
#  'success',
#  'suicide',
#  'attacktype1',
#  'attacktype1_txt',
#  'attacktype2',
#  'attacktype2_txt',
#  'attacktype3',
#  'attacktype3_txt',
#  'targtype1',
#  'targtype1_txt',
#  'targsubtype1',
#  'targsubtype1_txt',
#  'corp1',
#  'target1',
#  'natlty1',
#  'natlty1_txt',
#  'targtype2',
#  'targtype2_txt',
#  'targsubtype2',
#  'targsubtype2_txt',
#  'corp2',
#  'target2',
#  'natlty2',
#  'natlty2_txt',
#  'targtype3',
#  'targtype3_txt',
#  'targsubtype3',
#  'targsubtype3_txt',
#  'corp3',
#  'target3',
#  'natlty3',
#  'natlty3_txt',
#  'gname',
#  'gsubname',
#  'gname2',
#  'gsubname2',
# ...

# %%
#df.to_csv("UK_TA_05_19.CSV", index = False)

# %%
df["weaptype1_txt"].value_counts()
# Out:
# Explosives                                                                     449
# Incendiary                                                                     345
# Firearms                                                                       108
# Melee                                                                           35
# Unknown                                                                          8
# Vehicle (not to include vehicle-borne explosives, i.e., car or truck bombs)      6
# Other                                                                            4
# Sabotage Equipment                                                               2
# Chemical                                                                         1
# Name: weaptype1_txt, dtype: int64

# %%
df["propvalue"].isnull().sum()
# Out:
# 605

# %%
columns_name = [ 
'eventid',
'iyear',
'imonth',
'iday',
'approxdate',
'country_txt',
'provstate',
'city',
'location',
'summary',
'multiple',
'success',
'suicide',
'attacktype1_txt',
'targtype1_txt',
'targsubtype1_txt',
'gname',
'individual',
'nperps',
'nkill',
'nwound',
'propvalue',
'weaptype1_txt']

# %%
columns_name
# Out:
# ['eventid',
#  'iyear',
#  'imonth',
#  'iday',
#  'approxdate',
#  'country_txt',
#  'provstate',
#  'city',
#  'location',
#  'summary',
#  'multiple',
#  'success',
#  'suicide',
#  'attacktype1_txt',
#  'targtype1_txt',
#  'targsubtype1_txt',
#  'gname',
#  'individual',
#  'nperps',
#  'nkill',
#  'nwound',
#  'propvalue',
#  'weaptype1_txt']

# %%
test = df[columns_name]

# %%
test
# Out:
#           eventid  iyear  imonth  iday approxdate     country_txt  \
# 0    200501020019   2005       1     2        NaN  United Kingdom
# 1    200503190010   2005       3    19        NaN  United Kingdom
# 2    200503200012   2005       3    20        NaN  United Kingdom
# 3    200503260006   2005       3    26        NaN  United Kingdom
# 4    200503280004   2005       3    28        NaN  United Kingdom
# ..            ...    ...     ...   ...        ...             ...
# 953  201812200027   2018      12    20        NaN  United Kingdom
# 954  201812230034   2018      12    23        NaN  United Kingdom
# 955  201812270022   2018      12    27        NaN  United Kingdom
# 956  201812310012   2018      12    31        NaN  United Kingdom
# 957  201812310034   2018      12    31        NaN  United Kingdom
#
#             provstate         city  \
# 0    Northern Ireland       Kilrea
# 1    Northern Ireland      Belfast
# 2    Northern Ireland      Belfast
# ...

# %%
df = df[columns_name]

# %%
df.dtypes
# Out:
# eventid               int64
# iyear                 int64
# imonth                int64
# iday                  int64
# approxdate           object
# country_txt          object
# provstate            object
# city                 object
# location             object
# summary              object
# multiple              int64
# success               int64
# suicide               int64
# attacktype1_txt      object
# targtype1_txt        object
# targsubtype1_txt     object
# gname                object
# individual            int64
# nperps              float64
# nkill                 int64
# nwound              float64
# propvalue           float64
# weaptype1_txt        object
# dtype: object

# %%
df["nperps"].value_counts()
# Out:
# -99.0    759
#  1.0      79
#  2.0      41
#  3.0      27
#  4.0       9
#  15.0      3
#  5.0       2
#  6.0       1
# Name: nperps, dtype: int64

# %%
df["nperps"].isnull().sum()
# Out:
# 37

# %%
df['nperps'],df["nwound"] = df['nperps'].fillna(value = -98).astype('int64') , df['nwound'].fillna(value = -98).astype('int64')
# Out:
# /Users/nadavsmith/miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df['nperps'].value_counts()
# Out:
# -99    759
#  1      79
#  2      41
# -98     37
#  3      27
#  4       9
#  15      3
#  5       2
#  6       1
# Name: nperps, dtype: int64

# %%
test.isnull().sum()
# Out:
# eventid               0
# iyear                 0
# imonth                0
# iday                  0
# approxdate          947
# country_txt           0
# provstate             0
# city                  0
# location            237
# summary               0
# multiple              0
# success               0
# suicide               0
# attacktype1_txt       0
# targtype1_txt         0
# targsubtype1_txt    124
# gname                 0
# individual            0
# nperps               37
# nkill                 0
# nwound                2
# propvalue           605
# weaptype1_txt         0
# dtype: int64

# %%
df["nperps"].isnull().sum()
# Out:
# 0

# %%
df["nwound"].isnull().sum()
# Out:
# 0

# %%
df.dtypes
# Out:
# eventid               int64
# iyear                 int64
# imonth                int64
# iday                  int64
# approxdate           object
# country_txt          object
# provstate            object
# city                 object
# location             object
# summary              object
# multiple              int64
# success               int64
# suicide               int64
# attacktype1_txt      object
# targtype1_txt        object
# targsubtype1_txt     object
# gname                object
# individual            int64
# nperps                int64
# nkill                 int64
# nwound                int64
# propvalue           float64
# weaptype1_txt        object
# dtype: object

# %%
len(df["eventid"].value_counts())
# Out:
# 958

# %%
df['eventid'].astype("str").str.len().value_counts()
# Out:
# 12    958
# Name: eventid, dtype: int64

# %%
test = pd.DataFrame({'year' : list(df['iyear']),
                       'month' : list(df['imonth']),
                       'day' : list(df['iday'])})

# %%
pd.to_datetime(test)
# Out:
# ---------------------------------------
# TypeErrorTraceback (most recent call last)
# ~/miniconda3/lib/python3.7/site-packages/pandas/core/tools/datetimes.py in _convert_listlike_datetimes(arg, box, format, name, tz, unit, errors, infer_datetime_format, dayfirst, yearfirst, exact)
#     447             try:
# --> 448                 values, tz = conversion.datetime_to_datetime64(arg)
#     449                 return DatetimeIndex._simple_new(values, name=name, tz=tz)
#
# pandas/_libs/tslibs/conversion.pyx in pandas._libs.tslibs.conversion.datetime_to_datetime64()
#
# TypeError: Unrecognized value type: <class 'int'>
#
# During handling of the above exception, another exception occurred:
#
# ValueErrorTraceback (most recent call last)
# ~/miniconda3/lib/python3.7/site-packages/pandas/core/tools/datetimes.py in _assemble_from_unit_mappings(arg, errors, box, tz)
#     903     try:
# --> 904         values = to_datetime(values, format="%Y%m%d", errors=errors, utc=tz)
# ...

# %%
df["iday"].value_counts()
# Out:
# 12    48
# 11    42
# 8     39
# 9     39
# 16    38
# 22    37
# 5     37
# 15    37
# 26    37
# 30    36
# 28    35
# 13    33
# 10    31
# 14    30
# 6     30
# 18    29
# 7     29
# 21    28
# 3     28
# 23    27
# 4     27
# 17    27
# 29    26
# 25    26
# 24    25
# 1     25
# 2     25
# 27    24
# 19    24
# 20    22
# 31    16
# 0      1
# Name: iday, dtype: int64

# %%
df[df["iday"] == 0]
# Out:
#           eventid  iyear  imonth  iday    approxdate     country_txt  \
# 219  201110190011   2011      10     0  October 2011  United Kingdom
#
#     provstate       city location  \
# 219   England  Sheffield      NaN
#
#                                                summary  multiple  success  \
# 219  10/19/2011: On Wednesday, in Sheffield, Englan...         0        1
#
#      suicide                 attacktype1_txt targtype1_txt  \
# 219        0  Facility/Infrastructure Attack      Business
#
#                           targsubtype1_txt    gname  individual  nperps  \
# 219  Entertainment/Cultural/Stadium/Casino  Unknown           0     -99
#
#      nkill  nwound  propvalue       weaptype1_txt
# 219      0       0        NaN  Sabotage Equipment

# %%
df["iday"] = df["iday"].replace(0, 19)
# Out:
# /Users/nadavsmith/miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df[df["iday"] == 0]
# Out:
# Empty DataFrame
# Columns: [eventid, iyear, imonth, iday, approxdate, country_txt, provstate, city, location, summary, multiple, success, suicide, attacktype1_txt, targtype1_txt, targsubtype1_txt, gname, individual, nperps, nkill, nwound, propvalue, weaptype1_txt]
# Index: []

# %%
date = pd.DataFrame({'year' : list(df['iyear']),
                       'month' : list(df['imonth']),
                       'day' : list(df['iday'])})

# %%
date_col = pd.to_datetime(date)

# %%
date_col.rename("Date", inplace = True)
# Out:
# 0     2005-01-02
# 1     2005-03-19
# 2     2005-03-20
# 3     2005-03-26
# 4     2005-03-28
#          ...
# 953   2018-12-20
# 954   2018-12-23
# 955   2018-12-27
# 956   2018-12-31
# 957   2018-12-31
# Name: Date, Length: 958, dtype: datetime64[ns]

# %%
df1 = df

# %%
pd.merge(df1, date_col, left_index=True, right_index = True)
# Out:
#           eventid  iyear  imonth  iday approxdate     country_txt  \
# 0    200501020019   2005       1     2        NaN  United Kingdom
# 1    200503190010   2005       3    19        NaN  United Kingdom
# 2    200503200012   2005       3    20        NaN  United Kingdom
# 3    200503260006   2005       3    26        NaN  United Kingdom
# 4    200503280004   2005       3    28        NaN  United Kingdom
# ..            ...    ...     ...   ...        ...             ...
# 953  201812200027   2018      12    20        NaN  United Kingdom
# 954  201812230034   2018      12    23        NaN  United Kingdom
# 955  201812270022   2018      12    27        NaN  United Kingdom
# 956  201812310012   2018      12    31        NaN  United Kingdom
# 957  201812310034   2018      12    31        NaN  United Kingdom
#
#             provstate         city  \
# 0    Northern Ireland       Kilrea
# 1    Northern Ireland      Belfast
# 2    Northern Ireland      Belfast
# ...

# %%
df1
